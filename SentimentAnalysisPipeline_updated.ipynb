# %% [markdown]
# ## SETUP

# %%
# !wget http://setup.johnsnowlabs.com/colab.sh -O - | bash
# Out:
# --2021-12-17 15:53:28--  http://setup.johnsnowlabs.com/colab.sh
# Resolving setup.johnsnowlabs.com (setup.johnsnowlabs.com)... 51.158.130.125
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://setup.johnsnowlabs.com/colab.sh [following]
# --2021-12-17 15:53:29--  https://setup.johnsnowlabs.com/colab.sh
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh [following]
# --2021-12-17 15:53:29--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1275 (1.2K) [text/plain]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.25K  --.-KB/s    in 0s
#
# 2021-12-17 15:53:29 (48.7 MB/s) - written to stdout [1275/1275]
#
# setup Colab for PySpark 3.0.3 and Spark NLP 3.3.4
# Installing PySpark 3.0.3 and Spark NLP 3.3.4
#      |████████████████████████████████| 209.1 MB 61 kB/s
#      |████████████████████████████████| 133 kB 54.7 MB/s
#      |████████████████████████████████| 198 kB 57.0 MB/s
#   Building wheel for pyspark (setup.py) ... done

# %%
import pandas as pd
import numpy as np
import json
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from sparknlp.annotator import *
from sparknlp.base import *
import sparknlp
from sparknlp.pretrained import PretrainedPipeline
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
spark = sparknlp.start()

# %%
import re
def preprocessor(text):
  text = re.sub('<[^>]*>', '', text)
  emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
  text = re.sub('[\W]+', ' ', text.lower()) + ' '.join(emoticons).replace('-', '')
  return text

# %% [markdown]
# ## PER GENRE

# %% [markdown]
# Load IMDB data per genre

# %%
import pandas as pd
import glob
path = r'/content/drive/MyDrive/review_file' # use your path
all_files = glob.glob(path + "/*.csv")

# %%
df_inputs = {}
for i in range(len(all_files)):
  df_inputs[i] = pd.read_csv(all_files[i])

# %% [markdown]
# Clean IMDB data

# %%
data_cleaned = {}
for i in range(len(all_files)):
  data = df_inputs[i]
  data['remove_mentions'] = data['text'].str.replace('@\S+','')
  stop = stopwords.words('english')
  print(data["remove_mentions"])
  data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
  data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
  cleaned_df = pd.DataFrame()
  cleaned_df["text"] = data["final_reviews"]
  data_cleaned[i] = cleaned_df
# Out:
# 0                         a magnificent accomplishment."
# 1      he managed to save about 1100 Jews from being ...
# 2       while at the same time actually bringing ligh...
# 3       Spielberg himself has admitted that he tends ...
# 4       I think he'll be remembered for generations t...
#                              ...
# 869     I am not saying in any way that this was a me...
# 870                                                 i.e.
# 871     and so on...but this is not a film about two ...
# 872     but maybe Ted Turner will put into color for ...
# 873     especially in his final breakdown scene.Ralph...
# Name: remove_mentions, Length: 874, dtype: object
# 0        having every single detail of his work done i...
# 1        something no one has ever done before : inste...
# 2        was not so different than our hero Cobb. They...
# 3        pun intended. The movie explains (or at least...
# 4                                  Mal (Marion Cotillard)
#                               ...
# 2196     plus he's criminally charged with murdering h...
# 2197     I got bored of all of the action and was actu...
# 2198     for goodness sakes! Dicaprio is brilliant; in...
# 2199     an electricity of excitement that I had not s...
# 2200    Action Scenes awesomely sequenced(watch out fo...
# Name: remove_mentions, Length: 2201, dtype: object
# 0       screenplay and picture) even though it was re...
# 1                                                 actors
# 2                         but he's also very intelligent
# 3                                           respectively
# 4       that it drove me crazy. And I hated the movie...
#                              ...
# 626                               then!<br/><br/>Granted
# 627                            but much like the villain
# 628     which I think speaks ill for the direction ou...
# 629                              the story isn't too bad
# 630     Clarice Starling. Ted Levine does a wonderful...
# Name: remove_mentions, Length: 631, dtype: object
# 0                                                   drama
# 1        but it takes a lot to make me cry when I watc...
# 2        but so many of our problems are because we do...
# 3        his I.Q. is right below the average scores. B...
# 4                                                  action
#                               ...
# 1054                           he's always loyal to Jenny
# 1055                                   named Forrest Gump
# 1056     although somewhat warped.  I would recommend ...
# 1057                                         Forrest Gump
# 1058     I had no problem with those scenes.  But then...
# Name: remove_mentions, Length: 1059, dtype: object
# 0        Shawshank Redemption barely registered at the...
# 1        so I watched it. I have watched it many many ...
# 2        but while history looks back on Gump as a goo...
# 3        Shawshank will uplift you in ways that you ca...
# 4        yet it has an everlasting message.  Frank Dar...
#                               ...
# 2756                                      terrific acting
# 2757     especially Morgan Freeman who is a wonderful ...
# 2758     who becomes his best friend.  The film speaks...
# 2759                                                 fear
# 2760     I think this is a very good film.  The relati...
# Name: remove_mentions, Length: 2761, dtype: object
# 0        both a comedy AND a horror flick. Ghostly app...
# 1        and although the film is not very loyal to th...
# 2              unlike many horror-oriented films nowadays
# 3        from the drive to the Overlook to the final c...
# 4        to understand all the allusions to it in dail...
#                               ...
# 1069         a walking psychotic dream with lots of space
# 1070     and it doesn't work. She is whiny and ineffec...
# 1071     there aren't nearly enough scares to occupy t...
# 1072     if you want to reserve seeing pure crap for y...
# 1073     I noticed that the audience was laughing at a...
# Name: remove_mentions, Length: 1074, dtype: object
# 0        having every single detail of his work done i...
# 1        something no one has ever done before : inste...
# 2        was not so different than our hero Cobb. They...
# 3        pun intended. The movie explains (or at least...
# 4                                  Mal (Marion Cotillard)
#                               ...
# 2196     plus he's criminally charged with murdering h...
# 2197     I got bored of all of the action and was actu...
# 2198     for goodness sakes! Dicaprio is brilliant; in...
# 2199     an electricity of excitement that I had not s...
# 2200    Action Scenes awesomely sequenced(watch out fo...
# Name: remove_mentions, Length: 2201, dtype: object
# 0        but because it is presented both ways the hyp...
# 1                                            QT is back."
# 2        yes - Brad is on Movie poster ... but they ar...
# 3        Mike Myers impersonation of a British general...
# 4        sensational scene. Brad Pitt is also wonderfu...
#                               ...
# 1239     why can't more films look like this! Movie wa...
# 1240     cruel and opportunistic SS officer on the hun...
# 1241     if that makes sense. The pace was kind of slo...
# 1242     unburdened by gimmickry. <br/><br/>I can't sa...
# 1243     or an overlong and suspense-free violence-fes...
# Name: remove_mentions, Length: 1244, dtype: object
# 0                     call me crazy as I've just seen it
# 1                                   and very ""virtual""
# 2                                       I'm very serious
# 3       it's ironic that once again Pixar produces a ...
# 4       Kathy Najimy and Sigourney Weaver lend great ...
#                              ...
# 801                                        not sell toys
# 802     not just family films.<br/><br/>What I wasn't...
# 803                                              lovable
# 804                                   Brookback Mountain
# 805                                               loving
# Name: remove_mentions, Length: 806, dtype: object
# 0                         a magnificent accomplishment."
# 1      he managed to save about 1100 Jews from being ...
# 2       while at the same time actually bringing ligh...
# 3       Spielberg himself has admitted that he tends ...
# 4       I think he'll be remembered for generations t...
#                              ...
# 869     I am not saying in any way that this was a me...
# 870                                                 i.e.
# 871     and so on...but this is not a film about two ...
# 872     but maybe Ted Turner will put into color for ...
# 873     especially in his final breakdown scene.Ralph...
# Name: remove_mentions, Length: 874, dtype: object
# 0                      the pair find themselves locked up
# 1        so far outside the box that I immediately fel...
# 2        Marvel just made a film with a talking tree a...
# 3        turning a bunch of also rans into a must see ...
# 4         is emotional and humorous.<br/><br/>Peter Quill
#                               ...
# 1529                                  colorful characters
# 1530     fast forward 3 years and we've got its much a...
# 1531                                       in the generic
# 1532     who claims to be Star Lord's father. The intr...
# 1533     it felt burnt out by the end which no amount ...
# Name: remove_mentions, Length: 1534, dtype: object
# 0       and the story is so very engrossing.  Best of...
# 1       fascinating character.<br/><br/>The Green Mil...
# 2                   I didn't see one scene from the book
# 3                  and fortunately when it comes to cast
# 4                                         Doug Hutchison
#                              ...
# 817     ""The Green Mile"".  Stephen King's serial no...
# 818     for that is what I think it is.  Many great m...
# 819     but it left me confused with its hoaky approa...
# 820     and infuses the proceedings with a rote predi...
# 821                                   nothing!<br/><br/>
# Name: remove_mentions, Length: 822, dtype: object
# 0       making it one of the greatest films of the 90...
# 1                                           well-written
# 2            brutal world without hope that they inhabit
# 3              perhaps the outgrowth of a brilliant mind
# 4       the movie is slow paced  and takes it time to...
#                              ...
# 770                                   among other things
# 771                                      or at least NYC
# 772                                        watch ""Henry
# 773                                       Thomas Aquinas
# 774     a character must be in peril in some way or s...
# Name: remove_mentions, Length: 775, dtype: object
# 0       it tells you that it should have won best pic...
# 1       they criticized Adrien Brody's performance an...
# 2       as the isolated pianist tries to ensure his s...
# 3       crisp black and white that offered many incre...
# 4                                    alone and in hiding
#                              ...
# 513                                               mother
# 514     looking for a way to escape... See this movie...
# 515     or avoid their eventual fate in the Nazi conc...
# 516     true . It's so true to become unbelievable fo...
# 517     I was never for a single second bored or dist...
# Name: remove_mentions, Length: 518, dtype: object
# 0                     but comic book movie ever created."
# 1        we are finally told why the villains are the ...
# 2        technological genius to advance or improve Lu...
# 3                                everyone holds their own
# 4        the newest of the tragic modern icons present...
#                               ...
# 5664                   have a somewhat campy feel to them
# 5665     but it makes more sense on a regular-size scr...
# 5666                    deliver solid performances! HEATH
# 5667     the film truly does belong to Ledger. While h...
# 5668     who apparently is challenging Batman at a mor...
# Name: remove_mentions, Length: 5669, dtype: object
# 0        having every single detail of his work done i...
# 1        something no one has ever done before : inste...
# 2        was not so different than our hero Cobb. They...
# 3        pun intended. The movie explains (or at least...
# 4                                  Mal (Marion Cotillard)
#                               ...
# 2196     plus he's criminally charged with murdering h...
# 2197     I got bored of all of the action and was actu...
# 2198     for goodness sakes! Dicaprio is brilliant; in...
# 2199     an electricity of excitement that I had not s...
# 2200    Action Scenes awesomely sequenced(watch out fo...
# Name: remove_mentions, Length: 2201, dtype: object
# 0       jokes or slapstick - it's not that kind of co...
# 1                                       and Sea Biscuit)
# 2                             is the incredible humanism
# 3       the Dude's bemused stoicism at constant odds ...
# 4       but few do it as seamlessly and with such wit...
#                              ...
# 721                                           great film
# 722            loads of offbeat characters - the stanger
# 723                                         when in fact
# 724     could possibly wrest the title from Robinson'...
# 725                                             Germans
# Name: remove_mentions, Length: 726, dtype: object

# %% [markdown]
# SentimentAnalysis

# %%
MODEL_NAME='sentimentdl_use_imdb'
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = SentimentDLModel.pretrained(name=MODEL_NAME, lang="en")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# KeyboardInterrupt

# %%
result = {}
for i in range(len(all_files)):
  empty_df = spark.createDataFrame([['']]).toDF("text")
  pipelineModel = nlpPipeline.fit(empty_df)
  df = spark.createDataFrame(data_cleaned[i])
  result[i] = pipelineModel.transform(df)

# %%
from pyspark.sql.functions import countDistinct
for i in range(len(all_files)):
  save_res = result[i].select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")).select(F.expr("cols['1']").alias("sentiment")).groupBy("sentiment").count()
  res_final = save_res.toDF("sentiment", "count")
  pandas_res_final = res_final.toPandas()
  k = all_files[i][all_files[i].rfind('/')+1:-11]
  pandas_res_final.to_csv('/content/drive/MyDrive/IMDB_genre_sentiments_final/Sentiments'+k+'.csv')

# %% [markdown]
# Load Twitter data per genre

# %%
import pandas as pd
import glob
path = r'/content/drive/MyDrive/Movies-tweets/Sentiments' # use your path
all_files = glob.glob(path + "/*.csv")

# %%
df_inputs = {}
for i in range(len(all_files)):
  df_inputs[i] = pd.read_csv(all_files[i],lineterminator='\n')

# %% [markdown]
# Clean Twitter data

# %%
data_cleaned = {}
for i in range(len(all_files)):
  data = df_inputs[i]
  data['remove_mentions'] = data['tweets'].str.replace('@\S+','')
  stop = stopwords.words('english')
  data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
  data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
  cleaned_df = pd.DataFrame()
  cleaned_df["text"] = data["final_reviews"]
  data_cleaned[i] = cleaned_df

# %%
data_cleaned[0].to_csv("tweets_cleaned")

# %% [markdown]
# SentimentAnalysis

# %%
MODEL_NAME='sentimentdl_use_twitter'
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = SentimentDLModel.pretrained(name=MODEL_NAME, lang="en")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# sentimentdl_use_twitter download started this may take some time.
# Approximate size to download 11.4 MB
# [OK!]

# %%
result = {}
for i in range(len(all_files)):
  empty_df = spark.createDataFrame([['']]).toDF("text")
  pipelineModel = nlpPipeline.fit(empty_df)
  df = spark.createDataFrame(data_cleaned[i])
  result[i] = pipelineModel.transform(df)

# %%
from pyspark.sql.functions import countDistinct
for i in range(len(all_files)):
  save_res = result[i].select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")).select(F.expr("cols['1']").alias("sentiment")).groupBy("sentiment").count()
  res_final = save_res.toDF("sentiment", "count")
  pandas_res_final = res_final.toPandas()
  k = all_files[i][all_files[i].rfind('/')+1:-4]
  pandas_res_final.to_csv('/content/drive/MyDrive/Twitter_genre_sentiment_final/Sentiments'+k+'.csv')

# %% [markdown]
# ## PER MOVIE

# %% [markdown]
# Load IMDB data per movie

# %%
import pandas as pd
import glob
path = r'/content/drive/MyDrive/imdb_dataset/2_reviews_per_movie_raw' # use your path
all_files = glob.glob(path + "/*.csv")

# %%
df_inputs = {}
for i in range(len(all_files)):
  df_inputs[i] = pd.read_csv(all_files[i])

# %% [markdown]
# Clean IMDB data

# %%
data_cleaned = {}
for i in range(len(all_files)):
  data = pd.DataFrame()
  data['review'] = df_inputs[i]['review']
  # data = df_inputs[i]
  data['remove_mentions'] = data['review'].str.replace('@\S+','')
  stop = stopwords.words('english')
  # print(data["remove_mentions"])
  data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
  data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
  cleaned_df = pd.DataFrame()
  cleaned_df["text"] = data["final_reviews"]
  data_cleaned[i] = cleaned_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-17153c4d993b> in <module>()
#       7   stop = stopwords.words('english')
#       8   # print(data["remove_mentions"])
# ----> 9   data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
#      10   data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
#      11   cleaned_df = pd.DataFrame()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-28-17153c4d993b> in <lambda>(x)
#       7   stop = stopwords.words('english')
#       8   # print(data["remove_mentions"])
# ----> 9   data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
#      10   data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
#      11   cleaned_df = pd.DataFrame()
#
# <ipython-input-28-17153c4d993b> in <genexpr>(.0)
#       7   stop = stopwords.words('english')
#       8   # print(data["remove_mentions"])
# ----> 9   data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
#      10   data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
#      11   cleaned_df = pd.DataFrame()
#
# KeyboardInterrupt:

# %%
data_cleaned[0].to_csv("tweets_per_movie_cleaned")

# %% [markdown]
# SentimentAnalysis

# %%
MODEL_NAME='sentimentdl_use_imdb'
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = SentimentDLModel.pretrained(name=MODEL_NAME, lang="en")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# sentimentdl_use_imdb download started this may take some time.
# Approximate size to download 12 MB
# [OK!]

# %%
result = {}
for i in range(len(all_files)):
  empty_df = spark.createDataFrame([['']]).toDF("text")
  pipelineModel = nlpPipeline.fit(empty_df)
  df = spark.createDataFrame(data_cleaned[i])
  result[i] = pipelineModel.transform(df)

# %%
from pyspark.sql.functions import countDistinct
for i in range(len(all_files)):
  save_res = result[i].select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")).select(F.expr("cols['1']").alias("sentiment")).groupBy("sentiment").count()
  res_final = save_res.toDF("sentiment", "count")
  pandas_res_final = res_final.toPandas()
  k = all_files[i][all_files[i].rfind('/')+1:-4]
  pandas_res_final.to_csv('/content/drive/MyDrive/imdb_dataset/3_sentiments_per_movie/'+k+'.csv')

# %% [markdown]
# Load Twitter data per movie

# %%
import os
all_files = []
for root, subdirectories, files in os.walk('/content/drive/MyDrive/Movies-tweets'):
    # for subdirectory in subdirectories:
    #   print(subdirectory)      
    for file in files:
        if root[root.rfind('/')+1:] not in ['.ipynb_checkpoints','SentAnalysed','Sentiments']:
          all_files.append(os.path.join(root, file))
    #   print(root[root.rfind('/')+1:])
      # print(os.path.join(root, file))

# %%
df_inputs = {}
for i in range(len(all_files)):
  print(all_files[i])
  df_inputs[i] = pd.read_csv(all_files[i],lineterminator='\n')
# Out:
# /content/drive/MyDrive/Movies-tweets/SciFi/Inception.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Iron Man.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Matrix.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Back to the Future.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Avengers.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/V for Vendetta.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Truman Show.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Terminator 2_ Judgment Day.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Prestige.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Interstellar.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Eternal Sunshine of the Spotless Mind.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Star Wars_ Episode VII - The Force Awakens.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Jurassic Park.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Terminator.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Hunger Games.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Avengers_ Infinity War.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Mad Max_ Fury Road.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Gravity.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Alien.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Iron Man 3.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Captain America_ The Winter Soldier.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Blade Runner.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Martian.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Iron Man 2.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/A Clockwork Orange.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Captain America_ The First Avenger.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Man of Steel.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Avengers_ Age of Ultron.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Donnie Darko.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Spider-Man.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/District 9.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Black Panther.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Transformers.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Captain America_ Civil War.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/2001_ A Space Odyssey.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men_ Days of Future Past.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Logan.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men_ First Class.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Batman v Superman_ Dawn of Justice.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Aliens.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/12 Monkeys.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Rogue One_ A Star Wars Story.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Spider-Man 2.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Edge of Tomorrow.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Amazing Spider-Man.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Jurassic World.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Prometheus.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Star Trek.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Arrival.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Independence Day.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Looper.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Rise of the Planet of the Apes.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/I, Robot.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X2_ X-Men United.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Spider-Man 3.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Spider-Man_ Homecoming.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Limitless.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Matrix Reloaded.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Her.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Matrix Revolutions.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Children of Men.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Butterfly Effect.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men_ The Last Stand.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Oblivion.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Back to the Future Part II.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men Origins_ Wolverine.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Pacific Rim.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Star Trek Into Darkness.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Ex Machina.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Incredible Hulk.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Lucy.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Fifth Element.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Maze Runner.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Captain Marvel.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Elysium.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Amazing Spider-Man 2.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Wolverine.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/War of the Worlds.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Day After Tomorrow.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Armageddon.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/X-Men_ Apocalypse.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Transformers_ Revenge of the Fallen.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Terminator 3_ Rise of the Machines.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Hunger Games_ Mockingjay - Part 1.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Unbreakable.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Back to the Future Part III.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Transformers_ Dark of the Moon.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/A Quiet Place.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Godzilla.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/In Time.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Lost World_ Jurassic Park.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/28 Days Later....csv
# /content/drive/MyDrive/Movies-tweets/SciFi/E.T. the Extra-Terrestrial.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Ready Player One.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/The Thing.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Predator.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/2012.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Face_Off.csv
# /content/drive/MyDrive/Movies-tweets/SciFi/Terminator Salvation.csv
# /content/drive/MyDrive/Movies-tweets/Music/A Star Is Born.csv
# /content/drive/MyDrive/Movies-tweets/Music/Some Like It Hot.csv
# /content/drive/MyDrive/Movies-tweets/Music/8 Mile.csv
# /content/drive/MyDrive/Movies-tweets/Music/La La Land.csv
# /content/drive/MyDrive/Movies-tweets/Music/Whiplash.csv
# /content/drive/MyDrive/Movies-tweets/Music/Walk the Line.csv
# /content/drive/MyDrive/Movies-tweets/Music/Pitch Perfect.csv
# /content/drive/MyDrive/Movies-tweets/Music/Bohemian Rhapsody.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Pianist.csv
# /content/drive/MyDrive/Movies-tweets/Music/School of Rock.csv
# /content/drive/MyDrive/Movies-tweets/Music/Wayne's World.csv
# /content/drive/MyDrive/Movies-tweets/Music/Get Him to the Greek.csv
# /content/drive/MyDrive/Movies-tweets/Music/Dirty Dancing.csv
# /content/drive/MyDrive/Movies-tweets/Music/High Fidelity.csv
# /content/drive/MyDrive/Movies-tweets/Music/Pitch Perfect 2.csv
# /content/drive/MyDrive/Movies-tweets/Music/Ray.csv
# /content/drive/MyDrive/Movies-tweets/Music/Inside Llewyn Davis.csv
# /content/drive/MyDrive/Movies-tweets/Music/Begin Again.csv
# /content/drive/MyDrive/Movies-tweets/Music/This Is Spinal Tap.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Wedding Singer.csv
# /content/drive/MyDrive/Movies-tweets/Music/Bill & Ted's Excellent Adventure.csv
# /content/drive/MyDrive/Movies-tweets/Music/Rocketman.csv
# /content/drive/MyDrive/Movies-tweets/Music/Once.csv
# /content/drive/MyDrive/Movies-tweets/Music/Coyote Ugly.csv
# /content/drive/MyDrive/Movies-tweets/Music/Billy Elliot.csv
# /content/drive/MyDrive/Movies-tweets/Music/If I Stay.csv
# /content/drive/MyDrive/Movies-tweets/Music/Step Up.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Bodyguard.csv
# /content/drive/MyDrive/Movies-tweets/Music/Pirate Radio.csv
# /content/drive/MyDrive/Movies-tweets/Music/Hail, Caesar!.csv
# /content/drive/MyDrive/Movies-tweets/Music/To Rome With Love.csv
# /content/drive/MyDrive/Movies-tweets/Music/Crazy Heart.csv
# /content/drive/MyDrive/Movies-tweets/Music/Sing Street.csv
# /content/drive/MyDrive/Movies-tweets/Music/Tenacious D in the Pick of Destiny.csv
# /content/drive/MyDrive/Movies-tweets/Music/Nick and Norah's Infinite Playlist.csv
# /content/drive/MyDrive/Movies-tweets/Music/August Rush.csv
# /content/drive/MyDrive/Movies-tweets/Music/Music and Lyrics.csv
# /content/drive/MyDrive/Movies-tweets/Music/Three Colors_ Blue.csv
# /content/drive/MyDrive/Movies-tweets/Music/Yesterday.csv
# /content/drive/MyDrive/Movies-tweets/Music/Green Room.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Piano.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Doors.csv
# /content/drive/MyDrive/Movies-tweets/Music/Burlesque.csv
# /content/drive/MyDrive/Movies-tweets/Music/Saturday Night Fever.csv
# /content/drive/MyDrive/Movies-tweets/Music/Frank.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Last Song.csv
# /content/drive/MyDrive/Movies-tweets/Music/Footloose.csv
# /content/drive/MyDrive/Movies-tweets/Music/Youth.csv
# /content/drive/MyDrive/Movies-tweets/Music/La Vie En Rose.csv
# /content/drive/MyDrive/Movies-tweets/Music/Step Up 2_ The Streets.csv
# /content/drive/MyDrive/Movies-tweets/Music/Save the Last Dance.csv
# /content/drive/MyDrive/Movies-tweets/Music/Control.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Legend of 1900.csv
# /content/drive/MyDrive/Movies-tweets/Music/A Night at the Roxbury.csv
# /content/drive/MyDrive/Movies-tweets/Music/That Thing You Do!.csv
# /content/drive/MyDrive/Movies-tweets/Music/Coffee and Cigarettes.csv
# /content/drive/MyDrive/Movies-tweets/Music/Dreamgirls.csv
# /content/drive/MyDrive/Movies-tweets/Music/Top Secret!.csv
# /content/drive/MyDrive/Movies-tweets/Music/Black Snake Moan.csv
# /content/drive/MyDrive/Movies-tweets/Music/Walk Hard_ The Dewey Cox Story.csv
# /content/drive/MyDrive/Movies-tweets/Music/Popstar_ Never Stop Never Stopping.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Producers.csv
# /content/drive/MyDrive/Movies-tweets/Music/Shine.csv
# /content/drive/MyDrive/Movies-tweets/Music/Empire Records.csv
# /content/drive/MyDrive/Movies-tweets/Music/I'm Not There.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Soloist.csv
# /content/drive/MyDrive/Movies-tweets/Music/Pitch Perfect 3.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Chorus.csv
# /content/drive/MyDrive/Movies-tweets/Music/Departures.csv
# /content/drive/MyDrive/Movies-tweets/Music/Magic Mike XXL.csv
# /content/drive/MyDrive/Movies-tweets/Music/Cold War.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Runaways.csv
# /content/drive/MyDrive/Movies-tweets/Music/The Adventures of Priscilla, Queen of the Desert.csv
# /content/drive/MyDrive/Movies-tweets/Music/Rab Ne Bana Di Jodi.csv
# /content/drive/MyDrive/Movies-tweets/Music/Rock Star.csv
# /content/drive/MyDrive/Movies-tweets/Music/Climax.csv
csv
# /content/drive/MyDrive/Movies-tweets/Thriller/Fifty Shades of Grey.csv
# /content/drive/MyDrive/Movies-tweets/Thriller/The Bourne Legacy.csv
# /content/drive/MyDrive/Movies-tweets/History/Black Hawk Down.csv
# /content/drive/MyDrive/Movies-tweets/History/Amadeus.csv
# /content/drive/MyDrive/Movies-tweets/History/The Illusionist.csv
# /content/drive/MyDrive/Movies-tweets/History/Dunkirk.csv
# /content/drive/MyDrive/Movies-tweets/History/Hacksaw Ridge.csv
# /content/drive/MyDrive/Movies-tweets/History/Braveheart.csv
# /content/drive/MyDrive/Movies-tweets/History/Schindler's List.csv
# /content/drive/MyDrive/Movies-tweets/History/12 Years a Slave.csv
# /content/drive/MyDrive/Movies-tweets/History/The King's Speech.csv
# /content/drive/MyDrive/Movies-tweets/History/Troy.csv
# /content/drive/MyDrive/Movies-tweets/History/Hotel Rwanda.csv
# /content/drive/MyDrive/Movies-tweets/History/Gone with the Wind.csv
# /content/drive/MyDrive/Movies-tweets/History/The Patriot.csv
# /content/drive/MyDrive/Movies-tweets/History/Pearl Harbor.csv
# /content/drive/MyDrive/Movies-tweets/History/Bridge of Spies.csv
# /content/drive/MyDrive/Movies-tweets/History/Downfall.csv
# /content/drive/MyDrive/Movies-tweets/History/Lincoln.csv
# /content/drive/MyDrive/Movies-tweets/History/Les Misérables.csv
# /content/drive/MyDrive/Movies-tweets/History/Zero Dark Thirty.csv
# /content/drive/MyDrive/Movies-tweets/History/Apollo 13.csv
# /content/drive/MyDrive/Movies-tweets/History/Valkyrie.csv
# /content/drive/MyDrive/Movies-tweets/History/Munich.csv
# /content/drive/MyDrive/Movies-tweets/History/The Great Escape.csv
# /content/drive/MyDrive/Movies-tweets/History/Enemy at the Gates.csv
# /content/drive/MyDrive/Movies-tweets/History/Ben-Hur.csv
# /content/drive/MyDrive/Movies-tweets/History/21.csv
# /content/drive/MyDrive/Movies-tweets/History/Gandhi.csv
# /content/drive/MyDrive/Movies-tweets/History/Hidden Figures.csv
# /content/drive/MyDrive/Movies-tweets/History/Shakespeare in Love.csv
# /content/drive/MyDrive/Movies-tweets/History/The Impossible.csv
# /content/drive/MyDrive/Movies-tweets/History/The Last King of Scotland.csv
# /content/drive/MyDrive/Movies-tweets/History/First Man.csv
# /content/drive/MyDrive/Movies-tweets/History/Hero.csv
# /content/drive/MyDrive/Movies-tweets/History/Straight Outta Compton.csv
# /content/drive/MyDrive/Movies-tweets/History/Cinderella Man.csv
# /content/drive/MyDrive/Movies-tweets/History/Deepwater Horizon.csv
# /content/drive/MyDrive/Movies-tweets/History/Invictus.csv
# /content/drive/MyDrive/Movies-tweets/History/JFK.csv
# /content/drive/MyDrive/Movies-tweets/History/Cold Mountain.csv
# /content/drive/MyDrive/Movies-tweets/History/Barry Lyndon.csv
# /content/drive/MyDrive/Movies-tweets/History/Across the Universe.csv
# /content/drive/MyDrive/Movies-tweets/History/The Queen.csv
# /content/drive/MyDrive/Movies-tweets/History/The Monuments Men.csv
# /content/drive/MyDrive/Movies-tweets/History/Empire of the Sun.csv
# /content/drive/MyDrive/Movies-tweets/History/The 13th Warrior.csv
# /content/drive/MyDrive/Movies-tweets/History/Rang De Basanti.csv
# /content/drive/MyDrive/Movies-tweets/History/Glory.csv
# /content/drive/MyDrive/Movies-tweets/History/Defiance.csv
# /content/drive/MyDrive/Movies-tweets/History/We Were Soldiers.csv
# /content/drive/MyDrive/Movies-tweets/History/The Way Back.csv
# /content/drive/MyDrive/Movies-tweets/History/The Good Shepherd.csv
# /content/drive/MyDrive/Movies-tweets/History/Marie Antoinette.csv
# /content/drive/MyDrive/Movies-tweets/History/Good Night, and Good Luck..csv
# /content/drive/MyDrive/Movies-tweets/History/Elizabeth.csv
# /content/drive/MyDrive/Movies-tweets/History/All the President's Men.csv
# /content/drive/MyDrive/Movies-tweets/History/Silence.csv
# /content/drive/MyDrive/Movies-tweets/History/Frost_Nixon.csv
# /content/drive/MyDrive/Movies-tweets/History/United 93.csv
# /content/drive/MyDrive/Movies-tweets/History/The Last Emperor.csv
# /content/drive/MyDrive/Movies-tweets/History/The Other Boleyn Girl.csv
# /content/drive/MyDrive/Movies-tweets/History/Centurion.csv
# /content/drive/MyDrive/Movies-tweets/History/Mississippi Burning.csv
# /content/drive/MyDrive/Movies-tweets/History/Selma.csv
# /content/drive/MyDrive/Movies-tweets/History/The New World.csv
# /content/drive/MyDrive/Movies-tweets/History/The Duchess.csv
# /content/drive/MyDrive/Movies-tweets/History/World Trade Center.csv
# /content/drive/MyDrive/Movies-tweets/History/Malcolm X.csv
# /content/drive/MyDrive/Movies-tweets/History/The Grapes of Wrath.csv
# /content/drive/MyDrive/Movies-tweets/History/The Death of Stalin.csv
# /content/drive/MyDrive/Movies-tweets/History/The King.csv
# /content/drive/MyDrive/Movies-tweets/History/12 Strong.csv
# /content/drive/MyDrive/Movies-tweets/History/Seabiscuit.csv
# /content/drive/MyDrive/Movies-tweets/History/Elizabeth_ The Golden Age.csv
# /content/drive/MyDrive/Movies-tweets/History/The Water Diviner.csv
# /content/drive/MyDrive/Movies-tweets/History/Amistad.csv
# /content/drive/MyDrive/Movies-tweets/History/Quiz Show.csv
# /content/drive/MyDrive/Movies-tweets/History/The White Ribbon.csv
# /content/drive/MyDrive/Movies-tweets/History/Child 44.csv
# /content/drive/MyDrive/Movies-tweets/History/The Lost City of Z.csv
# /content/drive/MyDrive/Movies-tweets/History/Jackie.csv
# /content/drive/MyDrive/Movies-tweets/History/Airlift.csv
# /content/drive/MyDrive/Movies-tweets/History/Battleship Potemkin.csv
# /content/drive/MyDrive/Movies-tweets/History/Macbeth.csv
# /content/drive/MyDrive/Movies-tweets/History/Woman in Gold.csv
# /content/drive/MyDrive/Movies-tweets/History/Conquest 1453.csv
# /content/drive/MyDrive/Movies-tweets/History/The Young Victoria.csv
# /content/drive/MyDrive/Movies-tweets/History/K-19_ The Widowmaker.csv
# /content/drive/MyDrive/Movies-tweets/History/Thirteen Days.csv
# /content/drive/MyDrive/Movies-tweets/History/The Finest Hours.csv
# /content/drive/MyDrive/Movies-tweets/History/The Mission.csv
# /content/drive/MyDrive/Movies-tweets/History/Miracle.csv
# /content/drive/MyDrive/Movies-tweets/History/The Flowers of War.csv
# /content/drive/MyDrive/Movies-tweets/History/The Killing Fields.csv
# /content/drive/MyDrive/Movies-tweets/History/The Passion of Joan of Arc.csv
# /content/drive/MyDrive/Movies-tweets/History/A Bridge Too Far.csv
# /content/drive/MyDrive/Movies-tweets/History/Midway.csv
# /content/drive/MyDrive/Movies-tweets/History/The Longest Day.csv
# /content/drive/MyDrive/Movies-tweets/History/Cold War.csv
# /content/drive/MyDrive/Movies-tweets/History/Detroit.csv
# /content/drive/MyDrive/Movies-tweets/History/Hotel Mumbai.csv
# /content/drive/MyDrive/Movies-tweets/War/Fury.csv
# /content/drive/MyDrive/Movies-tweets/War/Full Metal Jacket.csv
# /content/drive/MyDrive/Movies-tweets/War/The Last Samurai.csv
# /content/drive/MyDrive/Movies-tweets/War/Platoon.csv
# /content/drive/MyDrive/Movies-tweets/War/Saving Private Ryan.csv
# /content/drive/MyDrive/Movies-tweets/War/Apocalypse Now.csv
# /content/drive/MyDrive/Movies-tweets/War/Casablanca.csv
# /content/drive/MyDrive/Movies-tweets/War/The Hurt Locker.csv
# /content/drive/MyDrive/Movies-tweets/War/Pan's Labyrinth.csv
# /content/drive/MyDrive/Movies-tweets/War/Inglourious Basterds.csv
# /content/drive/MyDrive/Movies-tweets/War/The Great Dictator.csv
# /content/drive/MyDrive/Movies-tweets/War/Grave of the Fireflies.csv
# /content/drive/MyDrive/Movies-tweets/War/The Deer Hunter.csv
# /content/drive/MyDrive/Movies-tweets/War/Tropic Thunder.csv
# /content/drive/MyDrive/Movies-tweets/War/Black Hawk Down.csv
# /content/drive/MyDrive/Movies-tweets/War/1917.csv
# /content/drive/MyDrive/Movies-tweets/War/Enemy at the Gates.csv
# /content/drive/MyDrive/Movies-tweets/War/Jojo Rabbit.csv
# /content/drive/MyDrive/Movies-tweets/War/The Bridge on the River Kwai.csv
# /content/drive/MyDrive/Movies-tweets/War/The Boy in the Striped Pajamas.csv
# /content/drive/MyDrive/Movies-tweets/War/Legends of the Fall.csv
# /content/drive/MyDrive/Movies-tweets/War/Dear John.csv
# /content/drive/MyDrive/Movies-tweets/War/Incendies.csv
# /content/drive/MyDrive/Movies-tweets/War/The Thin Red Line.csv
# /content/drive/MyDrive/Movies-tweets/War/Paths of Glory.csv
# /content/drive/MyDrive/Movies-tweets/War/The English Patient.csv
# /content/drive/MyDrive/Movies-tweets/War/13 Hours.csv
# /content/drive/MyDrive/Movies-tweets/War/The Book Thief.csv
# /content/drive/MyDrive/Movies-tweets/War/Ran.csv
# /content/drive/MyDrive/Movies-tweets/War/The Men Who Stare at Goats.csv
# /content/drive/MyDrive/Movies-tweets/War/Black Book.csv
# /content/drive/MyDrive/Movies-tweets/War/G.I. Jane.csv
# /content/drive/MyDrive/Movies-tweets/War/The Water Diviner.csv
# /content/drive/MyDrive/Movies-tweets/War/Judgment at Nuremberg.csv
# /content/drive/MyDrive/Movies-tweets/War/Doctor Zhivago.csv
# /content/drive/MyDrive/Movies-tweets/War/Beasts of No Nation.csv
# /content/drive/MyDrive/Movies-tweets/War/Patton.csv
# /content/drive/MyDrive/Movies-tweets/War/U-571.csv
# /content/drive/MyDrive/Movies-tweets/War/The Mountain II.csv
# /content/drive/MyDrive/Movies-tweets/War/Born on the Fourth of July.csv
# /content/drive/MyDrive/Movies-tweets/War/Stripes.csv
# /content/drive/MyDrive/Movies-tweets/War/The Dirty Dozen.csv
# /content/drive/MyDrive/Movies-tweets/War/Duck Soup.csv
# /content/drive/MyDrive/Movies-tweets/War/Underground.csv
# /content/drive/MyDrive/Movies-tweets/War/MASH.csv
# /content/drive/MyDrive/Movies-tweets/War/Come and See.csv
# /content/drive/MyDrive/Movies-tweets/War/Salò, or the 120 Days of Sodom.csv
# /content/drive/MyDrive/Movies-tweets/War/The Best Years of Our Lives.csv
# /content/drive/MyDrive/Movies-tweets/War/Windtalkers.csv
# /content/drive/MyDrive/Movies-tweets/War/All Quiet on the Western Front.csv
# /content/drive/MyDrive/Movies-tweets/War/Rules of Engagement.csv
# /content/drive/MyDrive/Movies-tweets/War/Macbeth.csv
# /content/drive/MyDrive/Movies-tweets/War/Hart's War.csv
# /content/drive/MyDrive/Movies-tweets/War/Kelly's Heroes.csv
# /content/drive/MyDrive/Movies-tweets/War/A Bridge Too Far.csv
# /content/drive/MyDrive/Movies-tweets/War/Stalag 17.csv
# /content/drive/MyDrive/Movies-tweets/War/No Man's Land.csv
# /content/drive/MyDrive/Movies-tweets/War/The Battle of Algiers.csv
# /content/drive/MyDrive/Movies-tweets/War/The Wind that Shakes the Barley.csv
# /content/drive/MyDrive/Movies-tweets/War/Where Eagles Dare.csv
# /content/drive/MyDrive/Movies-tweets/War/Son of Saul.csv
# /content/drive/MyDrive/Movies-tweets/War/Tae Guk Gi_ The Brotherhood of War.csv
# /content/drive/MyDrive/Movies-tweets/War/Uri_ The Surgical Strike.csv
# /content/drive/MyDrive/Movies-tweets/War/Mudbound.csv
# /content/drive/MyDrive/Movies-tweets/War/From Here to Eternity.csv
# /content/drive/MyDrive/Movies-tweets/War/Casualties of War.csv
# /content/drive/MyDrive/Movies-tweets/War/Heartbreak Ridge.csv
# /content/drive/MyDrive/Movies-tweets/War/War Machine.csv
# /content/drive/MyDrive/Movies-tweets/War/The Man Who Would Be King.csv
# /content/drive/MyDrive/Movies-tweets/War/Tigerland.csv
# /content/drive/MyDrive/Movies-tweets/War/La Grande Illusion.csv
# /content/drive/MyDrive/Movies-tweets/War/Zulu.csv
# /content/drive/MyDrive/Movies-tweets/War/Kagemusha.csv
# /content/drive/MyDrive/Movies-tweets/War/Love and Death.csv
# /content/drive/MyDrive/Movies-tweets/War/The Last Legion.csv
# /content/drive/MyDrive/Movies-tweets/War/1941.csv
# /content/drive/MyDrive/Movies-tweets/War/The Guernsey Literary and Potato Peel Pie Society.csv
# /content/drive/MyDrive/Movies-tweets/War/Au Revoir les Enfants.csv
# /content/drive/MyDrive/Movies-tweets/War/In the Land of Blood and Honey.csv
# /content/drive/MyDrive/Movies-tweets/War/Coriolanus.csv
# /content/drive/MyDrive/Movies-tweets/War/The Ottoman Lieutenant.csv
# /content/drive/MyDrive/Movies-tweets/War/Duck You Sucker.csv
# /content/drive/MyDrive/Movies-tweets/War/Lifeboat.csv
# /content/drive/MyDrive/Movies-tweets/War/Gettysburg.csv
# /content/drive/MyDrive/Movies-tweets/War/The Caine Mutiny.csv
# /content/drive/MyDrive/Movies-tweets/War/Victory.csv
# /content/drive/MyDrive/Movies-tweets/War/To Be or Not to Be.csv
# /content/drive/MyDrive/Movies-tweets/War/Da 5 Bloods.csv
# /content/drive/MyDrive/Movies-tweets/War/Cross of Iron.csv
# /content/drive/MyDrive/Movies-tweets/War/Stalingrad.csv
# /content/drive/MyDrive/Movies-tweets/War/Little Boy.csv
# /content/drive/MyDrive/Movies-tweets/War/Stop-Loss.csv
# /content/drive/MyDrive/Movies-tweets/War/The Alamo.csv
# /content/drive/MyDrive/Movies-tweets/War/Saints and Soldiers.csv
# /content/drive/MyDrive/Movies-tweets/War/Last Flag Flying.csv
# /content/drive/MyDrive/Movies-tweets/War/The Great Raid.csv
# /content/drive/MyDrive/Movies-tweets/War/Catch-22.csv
# /content/drive/MyDrive/Movies-tweets/War/Saboteur.csv
# /content/drive/MyDrive/Movies-tweets/War/Bloody Sunday.csv
# /content/drive/MyDrive/Movies-tweets/War/The Birth of a Nation.csv

# %% [markdown]
# files ignored:
# /content/drive/MyDrive/Movies-tweets/Comedy/American Pie.csv

# %% [markdown]
# Clean Twitter data

# %%
data_cleaned = {}
for i in range(len(all_files)):
  data = pd.DataFrame()
  data['review'] = df_inputs[i]['tweets']
  # data = df_inputs[i]
  data['remove_mentions'] = data['review'].str.replace('@\S+','')
  stop = stopwords.words('english')
  # print(data["remove_mentions"])
  data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
  data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
  cleaned_df = pd.DataFrame()
  cleaned_df["text"] = data["final_reviews"]
  data_cleaned[i] = cleaned_df

# %%
data_cleaned[0]
# Out:
#                                                   text
# 0     どの階層にいてもいつキックが来るか分かるようにしておかないといけないな キックする時 音楽...
# 1    1 3 na versão antiga tinha uma cena onde sam p...
# 2    rt songs close milestones hala hala 39 98m 40m...
# 3    rt christian eschatology core nazi ideology si...
# 4    rt baby teenage fuse know onf lore barcodes on...
# ..                                                 ...
# 366  rt incredible growth since inception 1989 refl...
# 367  rt you dream live in dream never awake from at...
# 368                                inception type shit
# 369  playlist shuffle inception starts playing auto...
# 370                                                 rt
#
# [371 rows x 1 columns]

# %% [markdown]
# SentimentAnalysis

# %%
MODEL_NAME='sentimentdl_use_twitter'
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = SentimentDLModel.pretrained(name=MODEL_NAME, lang="en")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# sentimentdl_use_twitter download started this may take some time.
# Approximate size to download 11.4 MB
# [OK!]

# %%
result = {}
for i in range(len(all_files)):
  empty_df = spark.createDataFrame([['']]).toDF("text")
  pipelineModel = nlpPipeline.fit(empty_df)
  df = spark.createDataFrame(data_cleaned[i])
  result[i] = pipelineModel.transform(df)

# %%
from pyspark.sql.functions import countDistinct
for i in range(len(all_files)):
  save_res = result[i].select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")).select(F.expr("cols['1']").alias("sentiment")).groupBy("sentiment").count()
  res_final = save_res.toDF("sentiment", "count")
  pandas_res_final = res_final.toPandas()
  k = all_files[i][all_files[i].rfind('/')+1:-4]
  pandas_res_final.to_csv('/content/drive/MyDrive/twitter_per_movie_sentiments/'+k+'.csv')

# %% [markdown]
# Twitter new movies:

# %%
import os
all_files = []
for root, subdirectories, files in os.walk('/content/drive/MyDrive/twitter_latest_movie_reviews'):
    for file in files:
        if root[root.rfind('/')+1:] not in ['.ipynb_checkpoints','SentAnalysed','Sentiments']:
          all_files.append(os.path.join(root, file))

# %%
df_inputs = {}
for i in range(len(all_files)):
  print(all_files[i])
  df_inputs[i] = pd.read_csv(all_files[i],lineterminator='\n')
# Out:
# /content/drive/MyDrive/twitter_latest_movie_reviews/spiderman.csv
# /content/drive/MyDrive/twitter_latest_movie_reviews/quietplace.csv
# /content/drive/MyDrive/twitter_latest_movie_reviews/notimetodie.csv
# /content/drive/MyDrive/twitter_latest_movie_reviews/dune.csv
# /content/drive/MyDrive/twitter_latest_movie_reviews/bw.csv

# %%
data_cleaned = {}
for i in range(len(all_files)):
  data = pd.DataFrame()
  data['review'] = df_inputs[i]['tweets']
  # data = df_inputs[i]
  data['remove_mentions'] = data['review'].str.replace('@\S+','')
  stop = stopwords.words('english')
  # print(data["remove_mentions"])
  data['remove_stop'] = data['remove_mentions'].apply(lambda x: " ".join(x for x in x.split() if x.lower() not in stop))
  data['final_reviews'] = data["remove_stop"].apply(lambda x: preprocessor(x))
  cleaned_df = pd.DataFrame()
  cleaned_df["text"] = data["final_reviews"]
  data_cleaned[i] = cleaned_df

# %%
MODEL_NAME='sentimentdl_use_twitter'
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = SentimentDLModel.pretrained(name=MODEL_NAME, lang="en")\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# sentimentdl_use_twitter download started this may take some time.
# Approximate size to download 11.4 MB
# [OK!]

# %%
result = {}
for i in range(len(all_files)):
  empty_df = spark.createDataFrame([['']]).toDF("text")
  pipelineModel = nlpPipeline.fit(empty_df)
  df = spark.createDataFrame(data_cleaned[i])
  result[i] = pipelineModel.transform(df)

# %%
from pyspark.sql.functions import countDistinct
for i in range(len(all_files)):
  save_res = result[i].select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")).select(F.expr("cols['1']").alias("sentiment")).groupBy("sentiment").count()
  res_final = save_res.toDF("sentiment", "count")
  pandas_res_final = res_final.toPandas()
  k = all_files[i][all_files[i].rfind('/')+1:-4]
  pandas_res_final.to_csv('/content/drive/MyDrive/twitter_latest_movie_reviews/'+k+'_twitter_sentiment.csv')
